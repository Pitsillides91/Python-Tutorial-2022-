# %% [markdown]
# #  Python Tutorial for beginners in Data Science

# %% [markdown]
# ## What is Python:
# - Python is a general purpose programming language
# - Supports structured and unstructured data
# - Used by developers, data analyst, data scientist, data engineers, software engineers & other
# - We will focus on data science and data analytics related code

# %%
import os
from IPython.display import Image
PATH = "C:\\Users\\pitsi\\Desktop\\Python Tutorials\\2022 Python Tutorial\\"
Image(filename = PATH + "Python Logo2.png",width=500, height=500)

# %% [markdown]
# ## What we will NOT cover:
# - "Hello world" examples
# - Things you will not use in your day to day life
# - Theories behind functions
# - Focus on practical applications using actual data

# %%
# Python Overview Visual
Image(filename = PATH + "Path Towards Python.png",width=1000, height=1000)

# %% [markdown]
# ## Python Tutorial Overview
#
# 1. Path towards Learning Python for Data Scientists & Data Analysts
#
#
# 2. How to Download and install Anaconda - Python - Jupyter Notebook
#
#
# 3. Numpy Tutorial
#
#     - Importing / installing packages
#     - Creating Arrays
#     - Arrays from lists
#     - Appending an Array
#     - Array indexing
#     - Array datatypes
#     - Array Maths
#     - Reshape & Transpose
#     - Broadcasting
#
#
#
# 4. Pandas Tutorial
#     - What is a Panda's Series
#     - What is a Dataframe
#     - Loading a CSV into a DataFrame
#     - Column Filtering
#     - Row Filtering
#     - Sorting the DF
#     - Summarising / Aggregating Data
#     - Creating New Calculated Fields
#     - For Loops
#
#
# 5. Joins & Unions
#     - Left Join
#     - Inner Join
#     - Full Join
#     - Cross Join
#     - Right Join - Why bother?
#     - Union All / Concat
#
#
# 6. Matplotlib Visuals
#     - Line graphs using Numpy
#     - Line graphs using Pandas
#     - Combo plots
#     - Plots using forloops
#     - Histograms
#     - Scatterplots
#
# 7. Seaborn Visuals
#     - What is matplotlib and how/why it's used
#     - Line Plots
#     - Bar Plots
#     - Histogram
#     - Box Plots
#     - Scatter Plots
#     - lmplot (combo of regplot() and FacetGrid)
#     - Sub Plots
#     - Pair Plots
#     - Join Plots
#     - Heat Maps
#
#
# 8. Machine Learning Models TBC

# %% [markdown]
# ## 2. How to Download and install Anaconda - Python - Jupyter Notebook

# %% [markdown]
# 1. Download Anaconda from: https://www.anaconda.com/products/individual
# 2. Install it
# 3. Launch Jupyter Notebooks
# 4. Create a new Python 3 Notebook

# %% [markdown]
# ## 3. Numpy Library Tutorial

# %%
# Logo
Image(filename = PATH + "Numpy logo.png",width=600, height=600)

# %% [markdown]
# ### What is Numpy?
#
# - NumPy is a python package / library that stands for 'Numerical Python'
# - It is used for scientific computing by using array objects
# - It uses array/vector and matrix operations which save coding time and execution time; no need for while loops in lists
#
# More details:
# https://numpy.org/

# %%
# What is an array
Image(filename = PATH + "arrays.jpg", width=500, height=500)

# %% [markdown]
# ## 3.1. Main Data Types
#
# - Int: Stands for integer - Whole Number
# - Float: Decimal numbers
# - Str: Stands for String - Characters
# - Date: It has year, month, day attributes
# - Datetime: combined set of dates and times

# %% [markdown]
# ##  3.2. Printing / Running cells

# %%
# passing values


# CTRL + Enter = Run

# %%
# Calculations

# %%
# Calculations 


# Basic + - / *


# formulas

# %%
# Creating an array without Numpy

# %%
# calculation without numpy

# %%
# In order to apply calculations without Numpy



# Notes: This takes time and memory for complex calculations, hence we use Numpy

# %% [markdown]
# ## 3.2. Importing / Installing packages

# %%
# Packages / libraries



# pip install numpy - in the terminal

# %% [markdown]
# ## 3.3. Creating Arrays
#
# A numpy array is a grid of values. All have the same type

# %%
# Creating an array

# %%
# Now, we can easily apply calculations on a Numpy array


# Look at the difference in the code before numpy and after

# %%
# Now, we can easily apply calculations on a Numpy array



# Basic + - / *


# formulas

# it will always return a numpy array with 4 numbers

# %%
# checking the number of elements per dimension

# %%
# Selecting / indexing elements from the array

# %%
# Indexing elements that don't exist (out of bounds)

# %%
# Creating error check to avoid stoping the script

# %%
# changing the elements of the array

# %%
# creating a 2 D array


#a.shape

# %%
# We can apply the same calculations as before now

# %%
# We can apply the same calculations as before now



# Basic + - / *


# formulas

# %%
# creating a 3x3 Matrix

#a.shape

# To flatten the matrix

# %% [markdown]
# ## 3.4. Creating an Array from a List

# %%
#shape


#specifying the type

# %% [markdown]
# ## 3.5. Appending an Array

# %%
# Appending an array - creating an array from 0 to 100

# %%
# calculations

# %% [markdown]
# ## 3.6. Array indexing

# %%
# first value is the row, second is the column

# %%
# selecting the first 2 arrays/lines

# %%
# selecting the second array/line alone

# %% [markdown]
# ## 3.7. Array datatypes

# %%
# Integer # Numpy choose the datatype

# %%
# Float  # Numpy choose the datatype

# %%
# Specify a datatype

# %% [markdown]
# ## 3.8. Numpy Array Basic Maths
#
# Mathematical functions operate elementwise on arrays

# %%
# creating the arrays

# %%
# SUM

# %%
# Minus

# %%
# Multiply

# %%
# Division

# %%
# Summing the array all-together

# %%
# Summing the array all-together

# %%
# sums the values by column

# %%
# sums the values by row

# %% [markdown]
# ## 3.9. Reshaping & Transpose

# %%
# reshaping

# %%
# flattens

# %%
#generate new array and reshape

# %%
# Transpose

# %%
# One way of Transp

# %%
# Another way

# %% [markdown]
# ## 3.10. Broadcasting
# Allows numpy to work with arrays of different shapes when performing arithmetic operations

# %% [markdown]
# #   # Please Like and Subscribe!!! Thank you!!!

# %% [markdown]
# # 4. Pandas Tutorial

# %%
# Logo
Image(filename = PATH + "pandas logo.png", width=500, height=500)

# %% [markdown]
# ## What is Pandas?
# - Pandas is a python package / library
# - Pandas is a library for data manipulation and analysis
# - Two main data structures: the Series and DataFrame

# %%
# Importing / Installing packages



# To install Pandas type "pip install pandas" to the anaconda terminal

# %% [markdown]
# ## 4.1. What is Panda's Series
# Series is a one-dimensional object (similar to a vector)

# %%
# Creating a Series by passing in a list without the Index

# %%
# Creating a Series by passing in a list & the Indexs

# %%
# Indexing / filtering the Series

# %% [markdown]
# ## 4.2. What is Pandas DataFrame
#
# DataFrame is like an Excel table / PivotTable. It is a tabular data structure comprised of rows and columns

# %%
# Creating a dataframe Manually

# %%
# Passing Values in the DataFrame

# %%
# Creating DataFrame from a List

# %%
# Creating DataFrame from an Array

# %%
 # Creating DataFrame from pandas series

# %%
# Transpose a DataFrame

#method 1


# method 2

# %% [markdown]
# ## 4.3. Loading a CSV file into a DataFrame

# %%
# This is to find out your current directory

# %%
# Loading the data


# runs all the data


#runs the first 5 rows


#runs the number of rows you select



# Raw Data Source: https://www.kaggle.com/hellbuoy/car-price-prediction

# %%
# Display the last N number of rows

# %%
# Shape

# %%
# Displays the information for our DF

# %%
# Displays the summary statistics for all numeric columns

# %% [markdown]
# ## 4.4. Column Filtering

# %%
# Exmp 1


# Exmp 2

# %%
# Exmp 3 -  Data Frame 2 columns +

# %%
# Exmp 4 -  unique column values

# %%
# Exmp 5 -  unique columns values

# %%
# Creating an Array from a df column

# exm 1


# exm 2


# it automatically turns the column into an array so we can apply calculations

# %%
# exm 3 - 2 columns

# %% [markdown]
# ## 4.5. Row Filtering

# %%
# selecting the first 10 rows

# %%
# exm 1: selecting the data where carbody = 'convertible'


# exm 2: selecting the data where carbody is not 'convertible'

# exm 3: selecting the CarName where carbody is not 'convertible'

# exm 4: selecting the CarName and carbody where carbody is not 'convertible'

# %%
# exm 5: selecting the CarName and carbody where genre in convertible and hatchback

# exm 6: selecting the CarName and carbody where genre is not in convertible and hatchback

# %%
# exm 7: selecting the CarName and carbody where CarName is like bmw

# exm 8: selecting the CarName and carbody where CarName is not like bmw

# %%
# exm 9: selecting the CarName and carbody where price > 10000

# exm 10: selecting the CarName and carbody where price < 10000

# exm 10: selecting the CarName and carbody where price is between 15000 and 20000

# %% [markdown]
# ## 4.6. Sorting the DF

# %%
# Exmp 1 - by Date


# Exmp 2 - passing it back v1


# Exmp 3 - passing it back v2


# Exmp 4 - by horsepower asc


# Exmp 5 - by horsepower desc

# %% [markdown]
# ## 4.7. Aggregating the DF - Creating summary Tables

# %%
# Exmp 1 - Total price


# Exmp 2 - Average horsepower


# Exmp 3 - max horsepower


# Exmp 4 - min horsepower


# Exmp 5 - min horsepower where price is > 20000

# %%
# carbody with the highest price

# %%
# Count the number of games per carbody

# %%
# show the total positive ratings per carbody


# show the  average positive ratings per carbody

# show the enginetype with the highest avg prices

# show the total price and avg horsepower per carbody

# %%
# show the total price per carbody and drivewheel

# show the total price and mean enginesize per carbody and drivewheel

# show the total price, No. of cars and mean enginesize per carbody and drivewheel

# %% [markdown]
# ## 4.8. Creating new fields

# %%
# create a field that shows the relationship between price and horsepower

# %%
# create a new field based on condition - if the price is higher or lowerer than the  average price of all the dataset


#raw_data

# %% [markdown]
# ## 4.9. For Loops

# %%
# Show if the price is above or below the average price of it's respective carbody
# There are multible ways to achieve this

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Show if the price is above or below the average price of it's respective carbody
# There are multible ways to achieve this

# creating the list we want to loop through


# creating the new field

# %%
# Show if the price is above or below the average price of it's respective fuelsystem
# There are multible ways to achieve this

# creating the list we want to loop through


# creating the new field

# %% [markdown]
# #   # Please Like and Subscribe!!! Thank you!!!
